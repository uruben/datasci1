# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
fb_df= pd.read_csv("Football.csv")

# %%
bf_df= pd.read_csv("Football.csv")

# %%
fb_df.Club.unique
# Out:
# <bound method Series.unique of 0      (BET)
# 1      (BAR)
# 2      (ATL)
# 3      (CAR)
# 4      (VAL)
#        ...
# 655    (UTR)
# 656    (AJA)
# 657    (PSV)
# 658      NaN
# 659    (PSV)
# Name: Club, Length: 660, dtype: object>

# %%
bf_df.Country.unique
# Out:
# <bound method Series.unique of 0             Spain
# 1             Spain
# 2             Spain
# 3             Spain
# 4             Spain
#            ...
# 655     Netherlands
# 656     Netherlands
# 657     Netherlands
# 658     Netherlands
# 659     Netherlands
# Name: Country, Length: 660, dtype: object>

# %%
len(fb_df)
# Out:
# 660

# %%
len(bf_df)
# Out:
# 660

# %%
list (set(fb_df.Club.unique()) - set(bf_df.Country.unique()))
# Out:
# ['(GIR)',
#  '(SCR)',
#  '(OSA)',
#  '(NAC)',
#  nan,
#  '(PAR)',
#  '(FOR)',
#  '(SOU)',
#  '(RSL)',
#  '(SEV)',
#  '(AVL)',
#  '(SOC)',
#  '(STE)',
#  '(NER)',
#  '(LEC)',
#  '(NEW)',
#  '(HEE)',
#  '(CEL)',
#  '(BIL)',
#  '(STP)',
#  '(CAR)',
#  '(CAE)',
#  '(LIV)',
#  '(RBL)',
#  '(BSC)',
#  '(BOA)',
#  '(NYC)',
#  '(LEI)',
#  '(ARS)',
#  '(TIG)',
#  '(EMM)',
#  '(NAN)',
#  '(LAZ)',
#  '(BOU)',
#  '(SCF)',
#  '(GIL)',
#  '(LEN)',
#  '(BOT)',
#  '(TOT)',
#  '(PAL)',
#  '(BOL)',
#  '(FLU)',
#  '(LEE)',
#  '(CFC)',
#  '(VIL)',
#  '(CAG)',
#  '(SAN)',
#  '(BEN)',
#  '(FIO)',
#  '(VDG)',
#  '(CSK)',
#  '(SPR)',
#  '(FER)',
#  '(LIS)',
#  '(ORL)',
#  '(BUR)',
#  '(AZA)',
#  '(CEA)',
#  '(HOF)',
#  '(LYO)',
#  '(MIN)',
#  '(HER)',
#  '(RAN)',
#  '(ANG)',
#  '(LAG)',
#  '(MPE)',
#  '(LOK)',
#  '(FEY)',
#  '(TWE)',
#  '(GET)',
#  'Sandro',
#  '(PSG)',
#  '(BOR)',
#  '(FAR)',
#  '(IMI)',
#  '(FRA)',
#  '(MAR)',
#  '(LIL)',
#  '(REI)',
#  'Santi',
#  '(HUE)',
#  '(VVV)',
#  '(RBB)',
# ...

# %%
len(list(set(fb_df.Club.unique()) - set(bf_df.Country.unique())))
# Out:
# 180

# %%
pd.merge(fb_df,bf_df, on='Club', how='inner')

# should return players for the same club
# Out:
#          Country_x    League_x   Club   Player Names_x  Matches_Played_x  \
# 0            Spain     La Liga  (BET)  Juanmi Callejon                19
# 1            Spain     La Liga  (BET)  Juanmi Callejon                19
# 2            Spain     La Liga  (BET)  Juanmi Callejon                19
# 3            Spain     La Liga  (BET)  Juanmi Callejon                19
# 4            Spain     La Liga  (BET)   Borja Iglesias                35
# ...            ...         ...    ...              ...               ...
# 5007   Netherlands  Eredivisie  Aitor   Cantalapiedra                 21
# 5008   Netherlands  Eredivisie    Tim          Matavz                 24
# 5009   Netherlands  Eredivisie  (CSK)    Chidera Ejuke                24
# 5010   Netherlands  Eredivisie  (RZA)     Haris Vuckic                23
# 5011   Netherlands  Eredivisie  (UTR)      Gyrano Kerk                24
#
#       Substitution _x  Mins_x  Goals_x   xG_x  xG Per Avg Match_x  ...  \
# ...
